# %% [markdown]
# #Loading RAW data from bronze Layer (ERP)

# %% [markdown]
# ## Init

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import StringType

# %% [markdown]
# ##Importing px_cat_g1v2 Data

# %%
df=spark.table("workspace.bronze.erp_px_cat_g1v2")
df.display()

# %% [markdown]
# ###Cleaning up pc_cat_g1v2 data

# %%
for field in df.schema.fields:
    if isinstance(field.dataType,StringType):
        df=df.withColumn(field.name,trim(col(field.name)))
# df.display()

# %% [markdown]
# ###Data Processing and Renaming Columns

# %%
RENAME_COLUMNS={
    'ID':'id',
    'CAT': 'category',
    'SUBCAT': 'sub_category',
    'MAINTENANCE': 'maintenance'
}
for old_name,new_name in RENAME_COLUMNS.items():
    df=df.withColumnRenamed(old_name,new_name)
df.display()

# %% [markdown]
# ### Loading erp_px_cat_g1v2 Data

# %%
(
  df.write
  .mode("overwrite")
  .format("delta")
  .saveAsTable("silver.erp_px_cat_az12")
)
